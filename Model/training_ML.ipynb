# %%
import pandas as pd
import os
import re
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
# https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f

# %%
current_path = os.getcwd()+'/'
dataset_path =  current_path+'Collected Datasets/'

# %% [markdown]
# # load dataset

# %%
df_train = pd.read_csv(dataset_path+'train.csv')
df_dev = pd.read_csv(dataset_path+'devel.csv')
df_test = pd.read_csv(dataset_path+'test.csv')

# %% [markdown]
# # combine train and test as train and dev as test

# %%
df_all = df_train.append(df_test)

# %% [markdown]
# # Data preprocessing

# %%
#this function removes all the punctuation and takes care of all the word
pattern = re.compile(r"[A-Za-z0-9\-]{3,50}")

# %%
#this function clean all the symbols and removes them from the text
df_all['clean_message'] = df_all['message'].str.findall(pattern).str.join(' ')
df_dev['clean_message'] = df_dev['message'].str.findall(pattern).str.join(' ')

# %%
#this displays the message with the emotion
df_all = df_all[['clean_message', 'emotion']]
df_dev = df_dev[['clean_message', 'emotion']]
df_all.sample(n=3)
# Out:
#                                           clean_message emotion
# 1583  comcast you charge 150 extra for sending someo...    fear
# 1958  pronounced ing However pretty sure over excite...    fear
# 2301  Does anyone know are both Sims dual sim phone ...    fear

# %%
df_dev.clean_message.values
# Out:
# array(['theclobra lol thought maybe couldn decide there was levity not',
#        'Nawaz Sharif getting more funnier than kapilsharmak9 day day laughter challenge kashmir baloch',
#        'Nawaz Sharif getting more funnier than kapilsharmak9 day day challenge kashmir baloch',
#        'tomderivan73 just people watch and enjoy rare show optimism',
#        'love family much lucky grateful smartassfamily love',
#        'love family much lucky grateful smartassfamily hilarious love',
#        'Casper10666 assure you there laughter but increasing anger the costs and arrogance Westminster',
#        'any trump supporters and Hillary haters wanna chirp some weak minded pandering liberals just tweet EmmyA2 snickerfritz04',
#        'Google caffeine-an sprightly lengthening into the corridor seo WgJ',
#        'This tweet dedicated back pain which not understand because youthful and spry Full life Vivacious',
#        'Bluebelle89 lsmith855 liking the optimism',
#        'rainy day cheerful sunshine Prussian want nothing but Prussian',
#        'Gronnhair buryprofs DittoBistro was indeed lovely and the team were incredibly attentive and the ball Cheese was lively gesture',
#        'Geminiak LondonNPC you welcome wordgeek nAlso good put face the twitter feed even was only cheery hello',
#        'your age the heyday the blood tame TheArtofCharm shakespeareaninsults hamlet elizabethan williamshakespeare',
#        'was embarrassed when she saw was like knvfkkjg she thinks stalkers then she starts waving all cheerfully inviting',
#        'Good most often doesn require all that much smile care relate and helpful Thanks Lakis Court Hotel cyprus',
#        '4-2 Canada final tomorrow WCH Predictions optimism Canadian',
#        'turn two weeks happy was darkest year yet elated that survived',
#        'TheNiceBot IndyMN thought the holidays could not get any more cheerful and then met you TheNiceBot',
#        'The smell freshly cut grass didn even cheer boy boy',
#        'NateBLoL was that clear American naturally flavored sparkling water',
#        'cheerful heart good medicine but broken spirit saps person strength Proverbs WednesdayWisdom',
#        'Somebody who has braved the storm brewing cheerful',
#        'Somebody who has braved the storm brewing',
#        'Ready for that nice breezy calm sunshine weather Autumn',
#        'gets better without explanation you just wake one morning and you just happy totally and utterly elated',
#        'Imagine how sad fans are gona when they get eliminated Man that gonna Nirvana religious experience rejoicing their misery',
#        'Heather that was hilarious MsHeatherBates pattonoswalt chrishansen AnthonyWeiner 15gets20 NYC',
#        'Val reminds one the cheerful witches that looks after Aurora Disney Sleeping Beauty GBBO',
#        'GameGrumps THANK YOU MUCH FOR COMING DETROIT going sob joyful rainbows now brb',
#        'far ours greet have raised 250 for HGatChristmas with more come sparkling CllrJohnFox simoncotton69',
#        'Each day what you make goals challenges business goals success photographer photography ThursdayThoughts',
#        'Each day what you make goals challenges business goals optimism happy success photographer photography ThursdayThoughts',
#        'you don respond email within fays you wifl killed animated gif the girl from The Ring',
#        'HobbitDay nHobbit give gifts their birthdays sharing the gift glee today Find something that makes you happy',
#        'incredible that anthony weiner has been caught chasing busty milkmaid across park double speed while jaunty music plays',
#        'len snart Mick nods would like that went back his food smiling finished',
#        'yungdoujin wouldn that basically sparkling water',
#        'absolutely love with Laurie Hernandez she adorable and always cheerful',
#        'HunterDean gives gleeful squeak and wraps around you All mine',
#        'diehimbeertonis She developed her forced smile can force myself describe little hearty maybe sanki biraz',
#        'When give cheerfully and accept gratefully everyone blessed Maya Angelou',
#        'new day live and smile Hope all the followers nice night day',
#        'DocBellsSwan peers down you eyes crinkling with mirth and affection love bonnie Belle',
#        'bruins 514 gorddownie thehipdotcom would TragicallyHip they can help TOYSFORASMILE make hospitalized sick kids smile',
#        'Chris would take full responsibility and would want all rejoice the memories all had with him',
#        'Communism Kills get the subway melt and make sure only hearty italian bread black olives are must though',
#        'hesham786 that the spirit optimism', 'hesham786 that the spirit',
#        'yiu don respond email within days you willxbe killed animated gif the girl froa The',
#        'harrietemmett great minds think alike rejoice',
#        'harrietemmett great minds think alike',
#        'Dolores thin lipped smile graced glossed lips she let blues peer over the woman constant delight always',
#        'airtelindia have some issues with broadband bill charged for the month before signed with airtel hilarious',
#        'airtelindia have some issues with broadband bill charged for the month before signed with airtel',
#        'Bridget Jones was joyous Worried would disappointed Most definitely was not chickflick giggles comethefuckonbridget',
#        'Metal keeps you young and spry and keeps your hair luxurious nYES nSHUT AND LISTEN',
#        'hate when singing and some idiot thinks they can just join with like this not fcking glee MeanRikonaBot',
#        'chencouture LMAO that slutty hater girl That video was hilarious',
#        'MichiganBromo Good optimism sir',
#        'billie21806 cnnbrk tell that your bodies cheering the deaths black people cops their fear killing',
#        'MacDsmash you should get some SSB Swedish delight',
#        'kwelbyroberts they will come and you will rejoice their arrival',
#        'Moment levity the B41 Baby want ISIS Give ISIS nMom Shh nBaby want ISIS nWest Indian woman She wants what nMom Ices',
#        'tomlinmayniac starting new challenge glee poll every day',
#        'How can rule mind nIt hilarious that you can',
#        'lifetime laughter the expense the death bachelor',
#        'Our tone voice like One Direction thoughtful and timid yet playful',
#        'Sioux Valley wins home competitive cheer invite with score 158 Dell Rapids second 138',
#        'Tutoring gives such exhilarating feeling love helping people',
#        'PhilGlutting Hey There Phil Glutting thank you for following appreciated smile',
#        'PhilGlutting Hey There Phil Glutting thank you for following appreciated',
#        'feels good get outside for minute and get some fresh air hard stay cooped inside all day breezy',
#        'feels good get outside for minute and get some fresh air hard stay cooped inside all day',
#        'r0Ils ppl get triggered over smiling they irrelevant',
#        'GigaFag pipertownsend snapchat new would beg differ optimism',
#        'GigaFag pipertownsend snapchat new would beg differ',
#        'hearty Jonza all friends and follower',
#        '1johndes ball watching amp Rojo header was equally dreadful',
#        'pessimist someone who when opportunity knocks complains about the noise mikeshumor',
#        '500 season all looking for this point depressing royals',
#        'Stars when you shine nYou know how feel nScent the pine nYou know how feel nFreedom mine know how feel feelin good',
#        'All want watch some netflix but stuck here class depressing',
#        'Buddha doesn possess enough power deliver you from your affliction',
#        'Donating Trump puts damper very exciting Cubs season Really bad look Ricketts family',
#        'Hello dear friends will back online this Friday night miss you sober sobriety recovery',
#        'ccrago was dreadful even after met the Catfish still thought was her',
#        'watching this uni reveal depressing miss stingrays',
#        'Public products high downhearted price tag consumer survey sum and substance OVth',
#        'Wow just watched Before You and was seriously one the most depressing movies life',
#        'kayleighmcenany DonaldJTrumpJr that really all you can offer for those who sacrifice daily keep you safe kayleighmcenany sad',
#        'kayleighmcenany DonaldJTrumpJr that really all you can offer for those who sacrifice daily keep you safe kayleighmcenany',
#        'Dyslexia the affliction frozen genius Stephen Richards',
#        'OHSOVICTORIOUS FaZeAdapt all seen coming sad But her Instagram comments her pics are funny Adapts fans blew',
#        'HedgehogDylan she would frown bit folding her arms why that every time need assistance someone expects lil',
#        'abra abra abra what you doing ears soul GoodMusic melancholy',
#        'feel like appendix don have purpose depressed alone lonely broken cry hurt crying life',
#        'Might RadioX tomorrow hopefully win new car current one stinks gone off milk grim',
#        'Season and Charlie still prick lost',
#        'pmo100 5liveSport heard talk something miss looks weary',
#        'Angelina Jolie can keep man one can Today mourn because Love dead',
#        'DxfyingGrxvity frustration looking Elphaba frown aggravation Her high pitched voice was growing more and more',
#        'CovinoandRich just heard back2back guess that why they call the blues amp she got the look but can only sing tickle sacks version',
#        'SOBRIETY trying make being sober fashionable can done zeroalcohol soberoctober clubsoda nomorehangovers sober',
#        'StaceyDavidson You thief and liberal mope investigated the financial services board for theft govt retirement funds THIEF',
#        'This shit hurting heart that how serious',
#        'Before the year ends probably get master 12s flu games true blues and space jams',
#        'AnjiDunlap droop leggings Are they wearing XXXL',
#        'trashcami this cured depression',
#        'This world has some serious issues should all therapy',
#        'had little bit extra money would blow the whole paycheck and one the two KygoMusic concerts serious',
#        'kempicepoland don think did and didn have the rucksack laptop his possession murky business that note away bed',
#        'what are you listen these days nBogum these days feel gloomy listen ccm spiritual song often nChurch oppa mode',
#        'feel like lost family member', 'life went from happy unhappy',
#        'you are endless journey figuring yourself out don discouraged when you don know who you are yet',
#        'bedrest since got out the hospital find unopened beer what Pour that shit out alcohol all for sober',
#        'LeePorter94 DomMcGovern Dom saw Notts county away looking for mufc away ticket will pay blues',
#        'LeePorter94 DomMcGovern Dom saw Notts county away looking for mufc away ticket will pay',
#        'But chronic sadness may mean there are underlying issues than getting sad occassionally over particular issue mhchat',
#        'Don depress yourself comparing yourself comparisons',
#        'Folk Band Thistle Down will replaced The Paul Edwards Quartet Laurel Bank Park Sat 11am 3pm due ill health jazz blues',
#        'Folk Band Thistle Down will replaced The Paul Edwards Quartet Laurel Bank Park Sat 11am 3pm due ill health jazz',
#        'GRIPLIKEAVICE wouldn mind didn you know threaten job when disagree Puts damper things',
#        'FFBren CDCarter13 included for maximum sadness',
#        'Barcabhoy1 course not Didn sink his studs into knee like Forrester',
#        'Soooo badly want dye hair dark but have never been dark before soooo torn',
#        'Eeevah14 don know try not fret sweet little pupper',
#        'thoroughly love zen and jumin and dont think even have the patience for either them irl old and weary',
#        'Virgin TrainsEC feel for the conductor tonight obviously taken grief over the last few weeks sounds weary apologising',
#        'GolfStrat out Rory starts What would your group look like him Hideki and Walker and throw Reed Knox the pine',
#        'HATE that there ads for depression amp mentalhealth meds That ONLY something your doctor can determine Everyone different ssri',
#        'Rooney yards off the pace League Cup game against Northampton Town Let that sink for moment MUFC',
#        'can WAIT work tomorrow with high fuck fever sarcasm nHopefully feel better tomorrow nBut doubt pessimism',
#        'Don disheartened you didn get the cards you wanted not the end the world E-Eh Y-You want cheer you',
#        'amateur author Twitter might the most depressing thing ever seen',
#        'yesterday finished watching penny dreadful and from all the beautiful things saw one question remains were the writers HIM fans',
#        'are about little over hour away will arrive soon not fret',
#        'Should stayed Dubai',
#        'Chalk dance notation entree manchester inasmuch corinthian products that discourage drag branding ARwuEVfqv',
#        'basically dead skin peel which sounds grim But literally gets rid much dead skin from your pores',
#        'aaahhhh little OtisRedding soothe the soul music',
#        'aaahhhh little OtisRedding soothe the soul music blues',
#        'Remembering those day when still did know kpop thinking about how sad your life was without Kpop fan',
#        'and for inconsolable Oxford academics Brussels should just ignore the Brexit vote and tell the can leave the ever wah',
#        'xOffWithMyHeadx They officially said all the episodes left future and despair and will delayed',
#        '340 892 All with weary task fordone nNow the wasted brands glow nWhilst the scritch-owl scritching loud AMNDBots',
#        'Common app just randomly logged out was writing the last part college essay and lost all',
#        'rather laugh with the rarest genius beautiful alliance with his own being where kept his sadness melancholy',
#        'you invest new film will stop asking you invest new film concessions crime despair shortsightedness celebrities',
#        'Just watched Django Unchained Other people may frown but titter delight',
#        'KeithOlbermann depressing how despicable Trump with policies campaigning bigotry amp rancour can close evil immoral disaster',
#        'ZubairSabirPTI pls dont insult the word Molna',
#        'ArcticFantasy would have almost took offense this actually snapped you',
#        'IllinoisLoyalty that Rutgers game was abomination affront God and man must never speak again',
#        'CozanGaming that what lisa asked before she started raging can call you heh',
#        'Sometimes get mad over something minuscule try ruin somebodies life not like lose your job like get you into federal prison',
#        'Sometimes get mad over something minuscule try ruin somebodies life not like lose your job like get you into federal prison anger',
#        'think Sam Canaday amp KYLEJDOWSON must actually have working like amp dowson brady because havent got any snap chat videos today',
#        'eyes have been dilated hate the world right now with the rage thousand fiery dragons need drink',
#        'huwellwell One chosen the CLP members seats are not for people dole out their mates elect candidates fuming',
#        'huwellwell One chosen the CLP members seats are not for people dole out their mates elect candidates',
#        'Yoshi OnoChin can you please not have Canadian players play players that lag atrocious fixthisgame trash sfvrefund',
#        'DailyMirror love how theres outrage that white man but was black man them BLM would all over regardless reason',
#        'being dean really saving lot ppl don snap nomore amp take much out',
#        'Sorry guys have absolutely idea what time cam tomorrow but will keep you posted fuming',
#        'Sorry guys have absolutely idea what time cam tomorrow but will keep you posted',
#        'Ding wearing the look man who just found his arch enemy bed with his missus angryman',
#        'Ding wearing the look man who just found his arch enemy bed with his missus angryman scowl',
#        'NETFLIXNCHILL fuck with madden way harder',
#        'TrussElise Obama must fuming lol',
#        'Hate when guys cant control their anger',
#        'HedgehogDylan she would frown bit folding her arms why that every time need assistance someone expects lil',
#        'Literally fuming fuck sake',
#        'TrueAggieFan that where Brian was Where was invite',
#        'TrueAggieFan that where Brian was Where was invite offended',
#        'DxfyingGrxvity frustration looking Elphaba frown aggravation Her high pitched voice was growing more and more',
#        'the most magical time the year Xmas party announced and the outrage commences Gotta love Silicon Valley millennials',
#        'LaureEve sitting here wrapped fluffy blanket with incense burning listening Bon Iver and drinking mulled wine there',
#        'RevTrevK Wolfman93011 Daraidernation EROCKhd Take out the numbers madden are low and have dropped and people are unhappy',
#        'wouldn have anger issues she didn have lying issues think about that one pow lies confusion',
#        'isthataspider dhodgs will fight this guy Don insult the lions like that But seriously they kinda are Wasted some the best players',
#        'Everybody talking about the first day fall but summer never gonna die revenge Drake',
#        'The rage has died down',
#        'Ananya just grabbed bible opened started reading and then said where they talk about burning people',
#        'All Brian does sleep and aggravate',
#        'komal sidhnani true nThey burning with other pleasure nPpl true love happiness everywhere',
#        'pbhushan1 IndianExpress your opinion this the worst delhi govt acrid bitter hypocrisy',
#        'pbhushan1 IndianExpress your opinion this the worst delhi govt acrid hypocrisy',
#        'live and die for mchanzo honeymoon crashing and burning the second they move together',
#        'For the first time madden career just set farm account Should make MOTM much easier',
#        'LeonWobYP off NCFC grudge match',
#        'Might just leave and aggravate bae',
#        'Realest ever relentless ever inevitable that win',
#        'Kik trade have fun conversation kik youraffair kik kikme messageme textme pics trade tradepics bored',
#        'Kik trade have fun conversation kik youraffair kik kikme messageme textme pics trade tradepics snap bored',
#        'You thirsty for the chance disagree the left that you don even realize when something affront your bigoted platform',
#        'the girl that just hit car not only did she get lucky scratch but also from being spared the wrath sleep deprived Kait',
#        'LiamCannon1 just too raging type properly',
#        'oow16 sting decent new song',
#        'scrubbed hands times before trying put them nEyeballs burning EvenMoreBlind accidentally scared the cat whilst screeching',
#        'Just joined pottermore and was sorted into HUFFLEPUFF fuming',
#        'Just joined pottermore and was sorted into HUFFLEPUFF',
#        'reluctantnicko Don ask you don get Apologies offended you All due respect Alan think you been fed duff info',
#        'miss gran singing Rawhide her deep baritone growl',
#        'Having baby born too soon lifechanging years and feels like only yesterday sad happy angry emotionalrollercoaster',
#        'Having baby born too soon lifechanging years and feels like only yesterday sad happy emotionalrollercoaster',
#        'UKBlogAwards ModishMale would always honest but great feedback opinion the brand don want offend them BlogHour',
#        'fluffysoftlouis insist that you give your best insult first',
#        'SSheil coincidentally watched Ulzana Raid last night brutally indignant filmmaking',
#        'RealJamesWoods KennyCoble saddest part this whole mess that all this anger misdirected they should march the WhiteHouse',
#        'Note self Stop laughing things that offend you get mad people NoteToSelf offended mad upset',
#        'think our defense here USC playing well just need fix few things offense and can win the PAC this year',
#        'Eat ass longer insult',
#        'Why have vanity sizes Now sizes evenXXS sometimes are too big WTF Dear corporate jerks Lithuania didn need this rant angry',
#        'Why have vanity sizes Now sizes evenXXS sometimes are too big WTF Dear corporate jerks Lithuania didn need this rant',
#        'MaddenFreestyle turn the game wanting play madden and before load game just turn off now',
#        'marcavis AntisocialJW2 always been fiery but never radical',
#        'Taking umbrage because Jimmy Carr claimed that Bilbo Baggins went Mordor out cats does Countdown Know your Baggins mate',
#        'Anger resentment and hatred are the destroyer your fortune today',
#        'Anger resentment and hatred are the destroyer your fortune today',
#        'spend even minutes with you and you already irritate seriously will bitch you out until you shut',
#        'Sting just too damn earnest for early morning listening',
#        'Sting just too damn earnest for early morning listening sting',
#        'Just seeing Alex revells face gets angry',
#        'HomeSwapperteam Spent months arranging swap new jobs etc now found out she been leading merry dance fuming with her',
#        'danbloom1 beware the fury weak king', 'JeanFranko growl',
#        'Sam Brown Law Never offend people with style when you can fake that you have break this Island',
#        'FluDino Event started everyone getting ready travel the lake rage where everything glows',
#        'TrevorHMoore paget old Scotland the right-wingers are the most rabid anti-nationalists Socialists are mostly favour',
#        'Jen ny69 People will always get offended everyone situation different Just because have kids doesn mean have settle',
#        'gayla weeks1 try not let anger seep into reviews but resent having time wasted books like that Time precious',
#        'hope hustle don offend nobody',
#        'Just watched Django Unchained Other people may frown but titter delight',
#        'Lol little things like that make angry',
#        'know this going one those nights where takes Act God fall asleep',
#        'This horrible Lewis Dunk has begun networking Neo-Geo with his holiday home Mexico',
#        'JeffersonLake speaking cobblers saw Ricky Holmes Charlton last week tracking back amp defending dread seeing Gorre ball',
#        '1johndes ball watching amp Rojo header was equally dreadful',
#        'Really Jumanji The Rock Jack Black and Kevin Hart are you kidding WTF ThisIsATerribleIdea',
#        'Really Jumanji The Rock Jack Black and Kevin Hart are you kidding WTF ThisIsATerribleIdea horrible',
#        'Losing Villa M0tivati0nQuote Most the things people worry about are things that won even matter them few months from now',
#        'Are you worrying worried n1Peter nThrow all your worry him because cares for you faith leadership worry mindfulness success',
#        'concerns amp anxiety don matter you then shall return the favor EyeMatter',
#        'There goes the butterflies stomach nervous anxietyproblems',
#        'There goes the butterflies stomach anxietyproblems',
#        'Evan McMullin TheBlazeRadio Classic SHITLIB bullshit Create horrible problem and then discuss how solve What PIMP',
#        'fatgirlhealthy MBSCBILL that what use violence and intimidation for polictical agenda aka terrorism',
#        'Honestly there are some awful people the internet smh',
#        'ccrago was dreadful even after met the Catfish still thought was her',
#        'madhav pastey moral the story never check mails the night Most notices have nothing much worry about ashwinikn',
#        'can easily forgive child who afraid the dark the real tragedy life when men are afraid the light Plato',
#        'All4 the android app designed buggy and work sporadically fire box shocking',
#        'All4 the android app designed buggy and work sporadically fire box',
#        'Having terrific Tuesday Crush today with the Power Treat your internet like Pizza PowerOf4',
#        'joey coops yes Hun Avoid all costs nightmare',
#        'joey coops yes Hun Avoid all costs',
#        'The Apocalypse has hit our gym and nothing what thought would nEveryone wearing vests What contagious afraid',
#        'The Apocalypse has hit our gym and nothing what thought would nEveryone wearing vests What contagious',
#        'You want bad service use frontier they have terrible service amp anybody better going complain better business',
#        'TheDappaMc also for chocolate Feast ice lolly proper shocking',
#        'AttentiAlGatto LOL Why would scare doesn make any sense all but doesn scare chuckles',
#        'officialy adopting BurhanWani Hizbul terrorist Pakistan NawazSharif cardinal mistake 2day tht haunt years UNGA',
#        'soozclifford Sure have Sydney are too tough too quick and their team pressure too much for the Cats handle Motlop Cowan',
#        'soozclifford Sure have Sydney are too tough too quick and their team pressure too much for the Cats handle Motlop Cowan timid',
#        'Okay Brace yourself will attempt first loaf bread the morning will use dutch oven will make the dough now nervous',
#        'Okay Brace yourself will attempt first loaf bread the morning will use dutch oven will make the dough now',
#        'spencer0415 awe love you kid',
#        'The 2nd step beating anxiety depression realising that not about waiting for Take action yourself now',
#        'AlaskaGurus adventuretweets agreed awe meet such beautiful powerful animals',
#        'BuzzFeed this houses will get into instestines and scare poop and shit pants',
#        'Nothing worse than uber driver that can drive awful',
#        'Nothing worse than uber driver that can drive',
#        'Varneyco FoxBusiness talk latest Chelsea Bombing Ahmad Khan Rahami trips Afghanistan Pakistan tcot terror',
#        'Varneyco FoxBusiness talk latest Chelsea Bombing Ahmad Khan Rahami trips Afghanistan Pakistan tcot',
#        'FrameOfAnAngel them here for answers and scare her death there won answers for nSo instead just',
#        'But was intrigued your style boy Always been sucker for wild boy alarm AnneMarieIAm',
#        'SAHARTHERAPPER unfollowed without hesitation',
#        'Watching Follows This super freaky movie scary',
#        'They friend shake your hand then kick door thas the way the game',
#        'And cried front guy last night And just been horrible week but only for week',
#        'Came work today hours late 1st thing hear the big boss has been waiting for you his office panic hateBeingLate',
#        'also had awful nightmare involving being sick where worms were involved was disgusted when woke',
#        'school classmate with music class and sang Hallelujah like god with friend were breathless',
#        'CNNPolitics can wait hear what had say about the brilliant Hawking should rich the poorest taste bully',
#        'CNNPolitics can wait hear what had say about the brilliant Hawking should rich the poorest taste',
#        'Awareness seek shelter Letgo Old habit chasing desires resultin anger fear worry Choose Satisfaction within Peace Relax',
#        'Ever been really lonely and your phone keeps blowing but you just can pick and respond people recluse issues',
#        'Modern Proverb Don let anyone intimidate you about being single most marriages end divorce',
#        'called fat pushed him into the lockers then threaten sue',
#        'Whatt trailerrrr karanjohar AnushkaSharma RanbirKapoor AishwaryaRaiBachchan COMPLETELY BLOWN awestruck longingformore',
#        'Whatt trailerrrr karanjohar AnushkaSharma RanbirKapoor AishwaryaRaiBachchan COMPLETELY BLOWN longingformore',
#        'have been seeing terrible terrible prescriptions this week What going',
#        'stephenfhayes Mustard gas hostile work environment not terrorism call OSHA not military',
#        'Dunno going the Yorkshire scare grounds when only lasted minute the Alton towers one before running out fire exit crying',
#        'LethalWeaponFOX This show SUCKS lame awful you even used the same names lol bad Failed notworth2minutes Off air SOON',
#        'Rooney shocking attempted cross', 'That awful miss from Rooney',
#        'Another fun fact afraid',
#        'Why upping rooms makes few apprehend leaving out charcoal ownership UnZU',
#        'don want speak front him afraid intimidate nopanicattack',
#        'don want speak front him nopanicattack',
#        'want woman who overcomes obstacles tackling them faith instead tiptoeing around them fear Renee Swope',
#        'When you scared press send bgoodthepoet PrayForMe ThisIsAGodDream career help fear heart HeartRacing',
#        'When you scared press send bgoodthepoet PrayForMe ThisIsAGodDream career help heart HeartRacing',
#        'RyanAbe awe yay thank god was worried',
#        'About weeks till can pick camera again Though think there group cemetery shoot october can make photography horror',
#        'About weeks till can pick camera again Though think there group cemetery shoot october can make photography',
#        'hollywooddivas TMZ Sports Idiots like Larry Sanders scare All How can Morons these days Rush Judge Police all facts yet thugs',
#        'Thanks for ripping off again Luthansa 400 not enough for one way flight man from Frk then for bag then free gate awful',
#        'Thanks for ripping off again Luthansa 400 not enough for one way flight man from Frk then for bag then free gate',
#        'T5ylw ansh a79l shy 7lw wayed nas whatsapp',
#        'The moment you bring her meet your best friend and you nervous thefriendtest',
#        'The moment you bring her meet your best friend and you nervous nervous thefriendtest',
#        'ChrissyCostanza and have social anxiety There many awkward things wrong with',
#        'chutneysupercat lovely brownie calling tuppytupperware its awful',
#        'Northampton are awful',
#        'really amazing the money they give some these nfl texans brock',
#        'really amazing the money they give some these nfl texans brock terrible',
#        'lukeshawtime terrible',
#        'mikefreemanNFL nIsn OBrien supposed some sort offensive genius awful',
#        'mikefreemanNFL nIsn OBrien supposed some sort offensive genius',
#        'Trying book holiday flights britishairways website becoming nightmare',
#        'Trying book holiday flights britishairways website becoming',
#        'Bout get dontbreathe here WarrenTheaters nervous icantholdmybreaththatlong',
#        'Bout get dontbreathe here WarrenTheaters icantholdmybreaththatlong',
#        'twitter users Tweeting twitter like playing game against the computer Where the life Everyone too afraid say something',
#        'ReaganBattalion That terrible thing accuse Scott Baio',
#        'Tweeting from the sporadic wifi the tube perilous',
#        'Tweeting from the sporadic wifi the tube',
#        'Southend players always haunt Man',
#        'start growing out mustache now can Pablo Escobar for Halloween',
#        'Not the best horror ever but like that the uncertainty',
#        'Hillary Clinton looked the other way the Saudi war women and their terror financing because they bought her off',
#        'AaliyahLove69 would intimidated but would like think would have manned and helped',
#        'horrible cos one can relate everyone happy and dandy one way another',
#        'CesarSampao thisisbolton don get started town centre Used every week not been for months horrible',
#        'CesarSampao thisisbolton don get started town centre Used every week not been for months',
#        'Gahh queue for minutes Now put through Sport dept cancel back queue again shocking',
#        'Gahh queue for minutes Now put through Sport dept cancel back queue again',
#        'Staff ryainair FR1005 Asked for info and told look online You get what you pay for Ryanair STN Airport Compensation',
#        'Staff ryainair FR1005 Asked for info and told look online You get what you pay for Ryanair STN Airport Compensation awful',
#        'adviser the European Union top court said Hamas and the Tamil Tigers should taken off the terror list lka',
#        'about 18mths ago signed Lumo Energy for their VirginAustralia Velocity deal months still points shocking',
#        'about 18mths ago signed Lumo Energy for their VirginAustralia Velocity deal months still points'],
#       dtype=object)

# %% [markdown]
# # Agorithm -- 1) Conversion to bag of words 2) Model generation using K-NN

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

X_train = df_all.clean_message.values
X_test = df_dev.clean_message.values
y_train = df_all.emotion.values
y_test = df_dev.emotion.values

# %%
text_clf = Pipeline([('tfidf', TfidfVectorizer(sublinear_tf=True, min_df=1, norm='l2', encoding='latin-1', stop_words='english', ngram_range=(1, 3), lowercase = True)),
                     ('clf', KNeighborsClassifier()),
                     ])
text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.74      0.61      0.67        82
#         fear       0.63      0.80      0.70       108
#          joy       0.77      0.48      0.59        71
#       normal       0.17      0.24      0.20        17
#      sadness       0.58      0.62      0.60        69
#
#     accuracy                           0.63       347
#    macro avg       0.58      0.55      0.55       347
# weighted avg       0.65      0.63      0.63       347

# %%
text_sentence = 'i love you'

# %%
text_clf.predict([text_sentence])
# Out:
# array(['joy'], dtype=object)
